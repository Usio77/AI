# %%
# Univarient analysis

# %%
# Importing essentials
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Praful\AppData\Local\Temp\ipykernel_20132\1113111627.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Loading file path into dataframe object
excel_file_path = 'D:\\GitHubProject\\AI\\Lab_2\\cancer_patient.xlsx' # Dataset's path (Use properties to distinguish betn csv and xlsx file)
df = pd.read_excel(excel_file_path) #pip install openpyxl (It is essential for excell type of files)

# %%
df.head(5) # To view the first five rows of dataframe
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
sns.countplot(data=df, x='Level') # Shows the distribution of each unique value in level
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
df['Gender'].value_counts() # Counts the no of different values in Gender.
# Out:
# Gender
# 1    598
# 2    402
# Name: count, dtype: int64

# %%
# Creating pie chart of values in level
df['Level'].value_counts().plot(kind='pie',autopct='%0.2f',colors = ['red','green','yellow','blue']) # autopct ensures the percentage is displayed in the chart
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram
plt.hist(df['Age']) # histogram of age
# Out:
# (array([ 67.,  98., 145., 259., 111., 186.,  63.,  10.,  51.,  10.]),
#  array([14. , 19.9, 25.8, 31.7, 37.6, 43.5, 49.4, 55.3, 61.2, 67.1, 73. ]),
#  <BarContainer object of 10 artists>)

# %%
# Plot the distribution of univarient set of observation (age)
sns.distplot(df['Age']) # distribution plot
# Out:
# C:\Users\Praful\AppData\Local\Temp\ipykernel_20132\281077872.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age']) # distribution plot
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Box plot of age
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df.describe() #  provides descriptive statistics of the numerical columns in used DataFrame
# Out:
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# ...

# %%
# Bivarient analysis

# %%
# Scatter plot
sns.scatterplot(x='Balanced Diet', y='Obesity',hue='Gender' , style='Fatigue',size='Age' ,data=df) 
# x = x axis ; y = y axis ; 
# hue = scatter plot will be colored according to it
# style = points will be styled according to its category
# size = size will be determined with the values of this category
plt.show()

# %%
# Bar plot
sns.barplot(x='Fatigue',y='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Fatigue', ylabel='Age'>

# %%
# Box plot
sns.boxplot(x='Gender',y='Age',hue='Fatigue',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
# Displot
sns.distplot(df[df['Gender']==1]['Age'],hist=False)
sns.distplot(df[df['Gender']==2]['Age'],hist=False)
# Out:
# C:\Users\Praful\AppData\Local\Temp\ipykernel_20132\3566819684.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Gender']==1]['Age'],hist=False)
# C:\Users\Praful\AppData\Local\Temp\ipykernel_20132\3566819684.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# HeatMap (Categorical - Categorical)
sns.heatmap(pd.crosstab(df['Weight Loss'],df['Gender']))
# Out:
# <Axes: xlabel='Gender', ylabel='Weight Loss'>

# %%
# pairplot
"sns.pairplot(df,hue='Gender')"
# Too many attributes so not possible with this dataseet
# Out:
# "sns.pairplot(df,hue='Gender')"

# %%
# Line plot
sns.lineplot(x='Age',y='Genetic Risk',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Genetic Risk'>

# %%
sns.heatmap(df.pivot_table(values='Age',index='Alcohol uses',columns='chronic Lung Disease'))
# Out:
# <Axes: xlabel='chronic Lung Disease', ylabel='Alcohol use'>

# %%
sns.clustermap(df.pivot_table(values='Age',index='Alcohol use',columns='Gender'))
